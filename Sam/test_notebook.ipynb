# %% [markdown]
# # Geojson dataset minimize

# %%
# import pandas as pd
import json

# %%
import json
import pandas as pd

# data = json.loads(datastring)
# df = pd.read_json('48.geojson')
# data['features'][0]['geometry'] #Your first point

data = json.load(open('48.geojson'))
print(data)
# df = pd.DataFrame(data["result"])


# print(df.to_string())
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
import pandas as pd

df = pd.read_json('48.geojson')

print(df.to_string())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_106620/818824098.py in <module>
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_json('48.geojson')
#       4
#       5 print(df.to_string())
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# ~\anaconda3\envs\pyvizenv\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
datastring = 

data = json.loads(datastring)
data['features'][0]['geometry'] #Your first point

# %%
df_us = pd.read_csv('../Data/SVI2018_US.csv')
df_us
# Out:
#        ST       STATE ST_ABBR  STCNTY             COUNTY         FIPS  \
# 0       1     ALABAMA      AL    1015            Calhoun   1015981901
# 1       1     ALABAMA      AL    1015            Calhoun   1015981902
# 2       1     ALABAMA      AL    1015            Calhoun   1015981903
# 3       1     ALABAMA      AL    1097             Mobile   1097003605
# 4       1     ALABAMA      AL    1097             Mobile   1097990000
# ...    ..         ...     ...     ...                ...          ...
# 72832  51    VIRGINIA      VA   51003          Albemarle  51003010903
# 72833  51    VIRGINIA      VA   51121         Montgomery  51121020202
# 72834  51    VIRGINIA      VA   51700  Newport News City  51700030100
# 72835  53  WASHINGTON      WA   53033               King  53033005302
# 72836  53  WASHINGTON      WA   53077             Yakima  53077000100
#
#                                                LOCATION  AREA_SQMI  E_TOTPOP  \
# ...
